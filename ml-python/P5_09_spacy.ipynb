# %%
import importlib
import os
from joblib import dump, load

import numpy as np
import pandas as pd

from bs4 import BeautifulSoup

from sklearn.model_selection import train_test_split

import spacy

import ml.prepare as mlprepare

data_path = "..\\data\\stackoverflow\\"
np.set_printoptions(precision=2, suppress=True)
pd.options.display.float_format = "{:,.2f}".format

# %%
def filter_top_tags(df, column, count=10, default=None):
    top_tags = mlprepare.prepare_multi_label(df,'Tags')[:count]
    ret = df[column].apply(lambda cell: [x for x in cell if x in top_tags])
    if default:
        ret = ret.apply(lambda cell: cell if len(cell)>0 else ['other'])
    return ret

def nltk_post_tokens(row):
#     title_tokens = tokenizer.tokenize(row['Title'].lower())
#     title_tokens = [ stemmer.stem(w) for w in tokenizer.tokenize(row['Title'].lower()) if w not in nltk_stop_words ] 
#     body_tokens = [ stemmer.stem(w) for w in tokenizer.tokenize(row['bs4'].lower()) if w not in nltk_stop_words ]
    post_tags = [ tag.name for tag in BeautifulSoup(row['Tags'], 'html.parser').find_all() if tag.name in valid_tags ]
#     return title_tokens, body_tokens, post_tags
    return post_tags

# %%
df = pd.read_pickle(data_path + 'bs4.pkl')
# df_base = pd.read_pickle(data_path + 'top50_tags.pkl')

# %%
tags_filename = "Stackoverflow_top_tags.csv"
df_tags = pd.read_csv(data_path + tags_filename)
valid_tags = df_tags['TagName'].tolist()

df['Tags'] = df.apply(nltk_post_tokens, axis=1)
df['Tags'] = filter_top_tags(df,'Tags', count=50, default='other')
df = df[['Title','bs4','Tags']]
df
# Out:
#                                                    Title  \
# 0      How to determine the smallest common divisor o...
# 1      How to use a trait object that contains a meth...
# 2      Why a named function declaration isn't hoisted...
# 3      Getting value of input causing flickering in R...
# 4                How to assign a vector of atomic types?
# ...                                                  ...
# 49995  NullReferenceException in SimpleInjector.Conta...
# 49996  How can I add grid lines to a catplot in seaborn?
# 49997  Standard deviation only for data that meets tw...
# 49998  How to properly raise exception in TensorFlow ...
# 49999              GLFW callbacks and OpenGL round robin
#
#                                                      bs4  \
# 0      I was asked the following question during a jo...
# 1      What's the correct way to use a trait object t...
# 2      is putting the function declaration beside the...
# 3      I am attempting to track the value of two logi...
# 4      How can I assign the members of a vector with ...
# ...                                                  ...
# 49995  I'm still in the process of getting into WPF a...
# 49996  How can I add grid lines (vertically and horiz...
# 49997  I am trying to calculate the standard deviatio...
# 49998  I want to raise a  exception dependent on the ...
# 49999  In a Round Robin fashion, you usually have a f...
#
#                              Tags
# 0                        [string]
# 1                         [other]
# 2                    [javascript]
# 3      [javascript, css, reactjs]
# 4                           [c++]
# ...                           ...
# 49995                        [c#]
# 49996                    [python]
# 49997                     [excel]
# 49998        [python, python-3.x]
# 49999                     [other]
#
# [50000 rows x 3 columns]

# %%
# categories = df.groupby('Tags').size().sort_values(ascending=True)
categories = mlprepare.prepare_multi_label(df,'Tags')
categories[:10]
# Out:
# python        8882
# other         6839
# javascript    5558
# r             4045
# pandas        3300
# java          2917
# c++           2688
# c#            2632
# python-3.x    2173
# sql           2032
# dtype: int64

# %%
df = df[['bs4','Tags']]
df
# Out:
#                                                      bs4  \
# 0      I was asked the following question during a jo...
# 1      What's the correct way to use a trait object t...
# 2      is putting the function declaration beside the...
# 3      I am attempting to track the value of two logi...
# 4      How can I assign the members of a vector with ...
# ...                                                  ...
# 49995  I'm still in the process of getting into WPF a...
# 49996  How can I add grid lines (vertically and horiz...
# 49997  I am trying to calculate the standard deviatio...
# 49998  I want to raise a  exception dependent on the ...
# 49999  In a Round Robin fashion, you usually have a f...
#
#                              Tags
# 0                        [string]
# 1                         [other]
# 2                    [javascript]
# 3      [javascript, css, reactjs]
# 4                           [c++]
# ...                           ...
# 49995                        [c#]
# 49996                    [python]
# 49997                     [excel]
# 49998        [python, python-3.x]
# 49999                     [other]
#
# [50000 rows x 2 columns]

# %%
data_train, data_test = train_test_split(df, test_size=.1, random_state=31)

# %%
df.shape
# Out:
# (50000, 2)

# %%
data_test.shape
# Out:
# (5000, 2)

# %%
nlp = spacy.load("en_core_web_sm")
# nlp = spacy.load("en")

# %%
nlp.max_length=2000000
# doc_title = nlp(df_base['Title'][:10000].str.cat(sep='. '))

# doc_body = nlp(df_base['bs4'][:3000].str.cat(sep='. '))

# %%
for label in categories.index[:10]:
    textcat.add_label(label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-58af5eb12c9f> in <module>
#       1 for label in categories.index[:10]:
# ----> 2     textcat.add_label(label)
#
# NameError: name 'textcat' is not defined

# %%
data_train_spacy = list(zip(
    df.bs4,
    df.Tags.apply(
        lambda cat: {'cats': { c: float(c == cat)
                             for c in categories.index[:10]}})
))

# %%
data_train_spacy
# Out:
# [("I was asked the following question during a job interview and was stumped by it. Part of the problem I had is making up my mind about what problem I was solving. At first I didn't think the question was internally consistent but then I realized it is asking you to solve two different things - the first task is to figure out whether one string contains a multiple of another string. But the second task is to find a smaller unit of division within both strings. It's a bit more clear to me now with the pressure of the interview room behind me but I'm still not sure what the ideal algorithm would be here. Any suggestions?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("What's the correct way to use a trait object that contains a method that returns a reference to ?   The following code gives the compiler error Now, we can resolve this in at least one of two ways.  Either, we can modify the definition of  to: or, we can modify the definition of bar to: That said, I don't understand the difference between the two and what circumstance either should be used or if another method should be used.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("is putting the function declaration beside the return statement causing the function not to hoist? or putting it inside the return statement turns it into a function expression that's why it isn't hoisted?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I am attempting to track the value of two login input fields by getting their value on change and storing this value in the local state so that when the user submits the login, I can just get the current values from the state. However, this results in the inputs flickering when I type text into them and also a weird glitch when I type in the password field (the cursor jumps back to the email field). The glitch can be observed below (note, I am not shift-tabbing back to the email field, it seems to be happening automatically for some reason when I type in the password field). The following is the code for my  which I have as a component nested within a navbar: My  component is as follows: My inputs are situated within a modal component which I display as an overlay using a portal. I have gone through related questions and tried using other methods but nothing seems to work. I appreciate any help!',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('How can I assign the members of a vector with an atomic type?  https://wandbox.org/permlink/lchfOvqyL3YKNivk',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have command like this: which extract for me output: the question is how to extract only reacthublh-network which is first key of json object? UPDATE: The only way that I found now is:  which outputs exactly what I need but I'm curious if it's still possible to do it in --format parameter",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Hello, happy new year ! I am currently thinking about making a simple poll app but I am not sure on how to store the choices and the vote count. Basically I have : string : question string: uid etc And here are the choices And here the vote count I was thinking about putting the choices and the count into an array choices : ["yes", "no"] votes : [0, 24] So the choice "yes" has the index 0, it has 0 vote, the choice "no" has the index 1, it has 24 votes, it does work well but when it comes to firestore security rules (if I understood correctly), I can check if there is always 2 items into the array, but I can\'t check the value of each item, so the user could change it for [35, 0] instead of let\'s say [1, 24]. The other idea was to store it into a map choices : {x0: "yes", x1: "no"} votes: {x0: 0, x1: 24} I assume the user could only modify a specific field, and I may be able to prevent the user from replacing the value by whatever he wants, but, I didn\'t find out how to let the user update a dynamic field (as I don\'t know which x[i] he is going to modify, and I don\'t know the amount of x[i]) So if you guys have any ideas or suggestions I will be pleased to hear them !',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("Packages on the Comprehensive R Archive Network (CRAN) can obviously directly import other packages that are on CRAN. Can packages on CRAN also import packages that are not on CRAN? - if not, I guess the options are: get the other package onto CRAN, or abstract out the necessary parts to include directly (rather than import the entire package) other methods?  I'm interested because sometimes a contribution makes more sense sitting in a separate package, especially if the contribution is likely to be used in its own right, or in other packages.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm trying to get the base::by() function to work in R. it's very similar to the base::tapply() function.  For some reason, the following code is not working correctly. I've tried this: but I get the following warnings: mtcars$mpg and mtcars$hp are numeric, so not sure why the mean() can't accept them as arguments.  Anyone know why this may be the case?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("please use here and copy the code in below to add context to my questions.  As you see, I have a table and within it certain Father's have the same name, I want to choose the  that has the most  for my final list. You can see the entire table in  , my desired result in  with respect to  returned, but when I am trying to get Father  in  to only return 1 time but it shows the entire record for Father John with 9 dogs and 10 dogs.  How can I get  to select only one Father whom has the Max Dogs, and return the rest of the columns as well?  Create tables code: Query #1 Query #1 OUTPUT: Query #2 Query #2 OUTPUT Query #3  Query #3 Output Desired Output from Query #3",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("Let's say we're solving a simple word count problem. There's a list and we're trying to find the word count of each word occurring in the list. Which pattern is faster here? pattern 1 pattern 2",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have figured out how to reject a purely alphabetical argument. I cannot figure out how to reject an alphanumeric user input while passing numeric inputs. Here is my relevant code: and my code goes on to successfully carry out the function of my program (save for this one bug). Any help would be much appreciated! This is for an edX cs50 homework assignment. I finished the whole assignment except for this bug. I searched for an answer for over 3 hours, to no avail. Help me, stack overflownobi. You're my only hope.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("So, I'm using PHP to try and separate a document into sections. A sample text is below. What I need is ANY text before the  symbol I need inserted into an array. The array should have the key of whatever is between the  symbols. I also would like to make sure to capture all new lines and quotation marks. However I'm not 100% sure this is possible. Basically I'm using the  symbols as breaks in the text. The document is around 96 pages long. So, I'm hoping to eventually be able to then put the results into separate text files with the name equal to the key in the array and the value as content in said text file. Example: I'm stuck because I'm not capturing new lines or quotation marks.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Is there a way to optimize this query by avoiding inner joins? I think the inner joins makes it very slow.   Edit 1:   Edit 2: These are DDL for the tables This is how my result looks Edit 3: I added Indexes with the help of workbench to the following columns: CitiBikeTrips.TripID.   CitiBikeTrips.Start_Time. O3_measurement.M_time O3_measurement.MStationID Any help is appreciated. Thanks!',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('How do I move all the Inputs and Outputs of a Parent Component into Typescript, rather than HTML? I have the following with a long list of parameters in Parent, sending and receiving data from Child Component. Would like them to be in Typescript. How can this be transferred?  Goal: The purpose is to make it easier for person to rearrange html/css to any liking, without worrying about copying inputs/outputs. If utilizing services, will that leave with strongly typed components, where parent and child are too connected? Prefer smart-dumb architecture strategy, if that is possible with services or not.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I know that the problem is within the last few lines but I don't know how to get around the problem. The problem is that each time  gets to negative, specifically less than , the code says that now  must multiply by  to go the other way. But, as soon as it is more than -1, the code is also telling it that when e is less than 0(which it is), . So what's happening is that it is fluctuating between  and . How do I get around this problem? P.S. This explanation is only what I think the problem is but it could be completely different.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I want to wrap each select element in   when they are inserted in a  having id "hook", the data is inserted using some ajax request that is not in my control. It works but some unwanted divs  are appearing and an error occurs: Uncaught RangeError: Maximum call stack size exceeded What I want: Prevent these unwanted divs that are highlighted in red color above the input type text. Is there any alternate of DOMNodeInserted available for better browser support. Here is my codepen: https://codepen.io/dmpak/pen/rNaGyPW HTML code jQuery code CSS code',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I am using Google Test to test C code but I encounter with the problem Write Stub for system functions like: fopen,fclose,fread,fwrite,memcpy,memset,stat,...I don't known how to Stub its input/output correctly to convenient for testing without having to care about real data. Example below:",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm trying to figure out how to expand a couple of rows with a date range in excel using Pandas. Below are two records that I want to expand in intervals of 7 days. Below is what I expect to see as as output. Should there not be enough for 7 days then I still want a row that shows the remaining days left. Below is a code that I drafted up. Quite new to using Pandas so I'm not sure if I'm using the methods correct here. If anyone would be able to help, that would be great! EDIT Big thank you to everyone below for responding! I learned a lot from hearing your responses. Below is the answer. Used Datanovice as the accepted answer.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm trying to set some environment variables which can be picked up by my bash script. order of execution: version.js script.sh but echo output is",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('For the above dict, if I try to access the value "S" by saying , compiler gives me a key error. I tried to look at other questions on here but I couldn\'t find answer. Error:',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have defined constant in Laravel as below Now what I wants to do is define new array within urlConstants which include another array like below But I wants to know that is there is any other way to access this variable rather than just typing the integers like below',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('So given a defination of a listnode class above. If I do  then Does that mean node 2 points to node1 or node1 now has a pointer to node2. and if I do  Does that mean we now have a node1->node2->node3 pointing this way?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Is there a way to do Commit only part of a file in Git in Sublime Merge?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have been doing some readings and thought about this code:  The output of this code is: 3 1 So what I assumed is for the 3, m & Value are aliased but changing m's attribute breaks this. I couldn't confirm this by running id() - it turned out m and value always had different ids.  Can someone explain what's going on?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I would like to generate a list of numbers who's digits are in ascending order. Is it possible for me to convert this probably to a recursion such that I can vary the nesting depth ?  Notes: In my application I have something other than printing and I'd like to keep minimum burden on the print statement. I am aware of the  and it's not suitable for my purpose as I have to remove the unnecessary combinations later.  Due to the same reason generating all  digit numbers and removing the unnecessary ones won't work as well  Thanks",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have 2 outputs from below commands  (Using SHELL) Output 1 Output 2 My actual output should be in excel. Like Output 1 should go to column 1 and Output 2 should go to column 2.  Kindly suggest.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Section 5.2.1.2.1 of the C11 standard states: A byte with all bits zero shall be interpreted as a null character   independent of shift state. Such a byte shall not occur as part of any   other multibyte character. Which, I think, makes it clear that a multibyte character can not have any of its bytes zero. If so, the below example should not work (because the characters contain zero bytes); but it does. Why? What am I missing here?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have an app where I want the user to be able to bookmark/un-bookmark a blog, but upon un-bookmarking, I don't want to remove that bookmark record. So I have an  property on my Bookmark model to determine whether a bookmark is active/inactive. In my test file, I have This test passes. However, the following won't. (Only difference is I do not assign a variable for the 's outcome.) It fails at the second assertion . Reason is that  does not get updated outside  function and is still , making it available in . (Definition attached below) For context, I am using classic mapping: The  function: I am really confused... My gut tells me that it has something to do when the query gets evaluated but I haven't managed to find any evidence to support it. Any help is appreciated. Thanks in advance! A full example:",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I\'m using  in   I\'m trying to run a simple hello world program but I got the error when  created.  kubelet does not have ClusterDNS IP configured and cannot create Pod using "ClusterFirst" policy. Falling back to "Default" policy Here is my deployment.yaml file which I\'m trying to apply.  Here is what I got when I try to  the pod I search alot about this I find some answers but no one is working for me I also create the  for this but don\'t know why this still is not working. These kube-dns are running. kube-dns are in  namespace.     And here is what I apply to create the   Please let me know what I\'m missing.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm using using Windows server and I'm having trouble logging in to SQL Server 2014. A few days ago I changed default user from master database to new one. But today I opened SQL Server Management Studio. I detach that database by right-clicking on it. After that, I disconnect from SQL Server Management Studio and then connect again. Check: Windows authentication Click OK I get an error: A connection was successfully established with the server, but then an error occurred during the login process. (provider: Shared Memory Provider, error: 0 - No process is on the other end of the pipe.) (.Net SqlClient Data Provider) error:233 When I try more to fixed it, now I get this error: Login Failed for user A. Reason: Server is in single user mode. Only one administrator can connect at this time (Microsoft SQL Server, Error: 18461) What causes this error and how do I login again and attach my database? Can I login to master database?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('The  state is one option behind when the  function triggers onChange of the . For example, Let\'s say the starting defaultValue option of  is "All",  is empty...the option is changed to "Medium",  is "All"...the option is changed to "Large",  is "Medium"...and so on. Initially I want the  function to run onload with "All" selected which is not working either, it throws the error Cannot read property \'target\' of undefined on . What am I doing wrong here? Thanks for the help.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('How to convert kotlinx.coroutines.flow list to normal data class list.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I saw this example from Flex: Scrollable div inside flex-column and attempted to use it, but I couldn't get it to work. Something is wrong, could someone look at my code and tell me where I went wrong with my code? A row that contains two columns; left is 75% width and right is 25% width. Right column height must be the same as the left column, therefore; when the right column has overflowing content, then right column should be scrollable. Live: http://gnt.staatus.eu/ Here's HTML code: and here's stylesheet:",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have a RecyclerView which there are three buttons in its model, how can I set a listener for each button? I can access RecyclerView's child and set a listener for it but I want to set a listener for a child of a child of RecyclerView. Consider that I'm using Kotlin. I used this code which let you access the child of recyclerView, but not the child of the child of RecyclerView:",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I am trying to store Address in HashMap but the compiler gives the  error:  Cannot figure out how to save this field into database. You can consider adding a type converter for it. private java.util.HashMap address; I am using the MapTypeConverter but it doesn't work Room Entity App DataBase",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('how can I separate each dataframe with an empty row ive combined them using this snippet so how can i split them with an empty row',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have dataframe: And I want to melt it to a dataframe that will look: Meaning, to melt based on the delimiter of the columns name.  What is the best way to do that?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I am implementing unqiue smart pointers with template and I keep getting the compiler error saying user-define conversion cannot specify the return type. Below is my code for both header and cpp files. The error occurs at line 15 of .h and line 48 of .cpp I have already tried using template  instead of using template  and it doesn't work either. And here is the cpp",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have 2 associative arrays resulting from 2 queries in JSON format below: These 2 arrays above generated by this code: I need to make a multidimensional array in php that will output the JSON below: How do I achieve this? I've been searching around on the net but seems like getting no luck. Any help will be much appreciated. Thank you.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm using this regular expression to remove an Arabic diacritical mark from a subtitle file, could it be modified to move the diacritical mark just one letter to the left instead of removing it? I'm using python 2.7. This is the original line in a subtitle file the diacritical mark is in its correct place أنا لا أترصّد عبر الإنترنت This is how i need it to be أنا لا أترصدّ عبر الإنترنت I'm using a media player that for some reason moves the diacritical mark one letter to the right, so to get the diacritical mark in its correct place when using this media player i need to move the diacritical mark one letter to the left in the subtitle file. https://github.com/xbmc/xbmc/issues/17076",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("can anyone explain how z-index default value works in this snippet  I expected sub ul to be on the top but I don't know how text from top level wrapped over text from lower level ? I can notice sub ul [red one] on the top and it can hide the top level border So I expected that ul here working like container so every child element will follow it I know If I give it z-index:1  will resolve it but I hope to understand the situation here if is possible",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I am basically scraping some content off of a website and the HTML looks something like this: Now after scraping this off of the website I use js to get the href attribute like this: Now the problem is that this returns:  but the result I want is . Here's a Stack Snippet example of the same problem - the  results in the domain being prepended, which is undesirable: I can fix this problem with basic string manipulation but that seems rudimentary. Also  is the drive on my computer the  drive. If I run this on another computer then it will become , representing the  drive. It might also help to know that I am doing this on an electron app using nodeJS.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I wanna create a user had random password for FTP in Docker. The section of Dockerfile like below: But I got an error in last line: Why the passwords do not match even I using a same variable? update: I found the output of  is: Why it's not works for  and where are my $ftppass? Resolved, the new section of Dockerfile is: Thanks anyone and happy new year~",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I want to incrementally grow a new column, based on values of the previous row & same column. You could do it with a loop, like so: (As you see, new values in column x use values of column x of the previous row.) However, as I do this for a Shiny app, I need to have fast calculation, thus using loops is not optimal. Is there a way of doing this which avoids loops, ideally making use of dplyr's piping? This reply (Referring to previous row in calculation) suggests a way using sapply - however, I am unable to do this mathematically...",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm trying to generate a stereo sine wave using FFMPEG (batch file), but have a different frequency for left and right. So far I have this: But it creates the same frequency for both left and right. Is this possible?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('We have a map of Student to record . Student class is as follows: Additionally, we have a list of Student Id  provided. Using Java streams, what would be the most efficient way to filter out records of students whose Id exists in the provided list? The expected outcome is the filtered list mapped against the Id(String) -',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Consider the MWE below. I would like to generate boxplots with these ideas in mind:  on the y-axix ordered according to  for , while  (1:40) on x-axis show mean points overlaying the boxes boxplots of  to be ordered based on median of  Site from  data text annotations of  of observations (to be taken from  data) MWE Summary code  ggplot code Graph I was expecting to see boxplots here. Adding annotation Unfortunately, this doesn\'t work either. Note tidyverse version is 1.3.0 R version 3.6.2 (2019-12-12) -- "Dark and Stormy Night"',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Currently, I am manually copying class A object to B like  Is there any alternate way to do something like',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm using a python library that inserts tasks into a DB, with a few tens of tasks every second. Every task has a unique identifier, and if the task already exists in the DB the library updates it instead. The way the library does it is always inserting, catching the PK violation error from the DB and updating. Is there a cost to using this method of constant PK violation instead of selecting first to see whether the task already exists or using ON CONFLICT? Does some error-handling get invoked in the DB every time, causing reduced performanc? This is an external library and I would like to know if I should implement the logic myself. The specific DB I'm using is postgres, if it makes a difference.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I used R's max function in combination with the  function from the  package and had a typo in the  function's argument . Mistakenly I wrote  and the script worked without any warning message and returned wrong values.  When replacing the  with  on a simple vector (outside  environment), the function returns the right values, and if the input vector holds  then it returns an  value without any warning about wrong argument used.  Here is an example: Does anybody know if ns.rm is a legitimate input argument of any R function?  If not, why there is no warning that the argument used is not used appropriately?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I am trying to create an array which is symmetric with elements placed as below I have written the following code to get this form with parameter being 0.5 and dimension being . This does what I need but for large dimension (1000s) this causes a lot of overhead. Is there any other low complexity method to get this matrix? Thanks.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('i have a custom view that is a 85% of a circle ( Just Stroke ) with Gradient color . here is my code :  but the edges are clipped  i have tried a lot but i cant fix it . one more thing is that when i change the radius manually the view wont be centered',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm new to C and programming in general. It's a guessing game where the user has a certain amount of guesses to guess whatever the hidden message is. Unfortunately, even if I enter the correct word, it does not register it as being correct. How do I structure this to ensure that if a Guess occurs correctly within the number of tries it runs",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm going to create a zip file from some of the image files stored on my server. I've used the following function to do this: Everything is fine and all photos are made in zip file but there is only one problem.  The problem is that the photos won't open and this error will appear in Windows: What is wrong with my codes?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("Let's say I have an array like this: I want to join each element in each row, so something like this: And I can do that with: But how do I achieve concatenation with a separator? But can't seem to find a way without . Is there an  function in numpy that can do this? Found a  method in  but it doesn't seem to work as I expected. Or,  doesn't work, which is surprising to me, given this works: I didn't find any question here that answers my issue exactly. Can someone help me out? EDIT: I am really going for speed here, if this is achievable in  that would do as well. EDIT 2: This question does not answer mine, as it uses comprehensions or uses lists as rows for the array, which I can't afford.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I am receiving response from server like below. Here,  and  are in separate object and the booking_id is same. Then I have created a Modal struct to store the data coming from server. and I am using it as,  Question : How to merge the two objects to create one final object. So basically, I want it to make it like this:  UPDATE More detail on what actually I am trying to achieve: if there are four records in json like this :  I need to merge booking1 and booking2 like this: I hope its much clear now.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have a dataframe with a  column. Each cell in that column has 5-10 individual values (comma seperated) which consist of 1 - 3 words. How can I count the most occurring keywords in the column? I have tried  but it returns all values for each cell because they obviously don't occur multiple times within each cell. Here an image to clarify: All input is appreciated, Thanks!",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('In this code,  does not need to be , but the compiler forces  to be : This is the only way I have found to get close to what I actually want:  a global, immutable  to be used by several functions, without littering all my code with  blocks. I know that a global variable is a bad idea for multi-threaded applications, but mine is single threaded, so why should I pay the price for an eventuality which will never arise? Since I use  directly and not , I don\'t want the "help" of extern crates like . I tried to decypher what the macro in that package does, but to no end. I also tried to write this with  and a  but I had trouble using  to initialize  with that version. In more general terms, the question could be "How to get stuff into the initvars section of a program in Rust?" If you can show me how to initialize  directly (without a function like ), your answer is probably right.   If a function like  is inevitable, is there a trick like an accessor function to reduce the  litter in my program?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I am looking at https://github.com/iputils/iputils/blob/s20161105/ping.c and I see from lines 608-713:  Two questions: How it compiles What is the value of adding  after if statement',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm getting different results testing a simple java class on Windows cmd and wsl (ubuntu). The java class: I use this test arguments: In cmd, the single quote doesn't group the arguments: cmd results and java version but in ubuntu, it does: wsl results and java version Any idea why this is happening?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have tried  it's working fine but my requirement is to hide it after initialization.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I added an , just as on W3Schools. But something somehow goes wrong, since clicking on the button does not reveal the collapsible content. I think it may have something to do with the script(s), though the  keeps on being sticky and responsive(which is good). Could anyone help me out?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I am writing a bash script which has a json value stored in a variable now i want to extract the values in that json using Jq. The code used is.  This throws an error of no such file or direcotry. If i change this to  This does not throws any error but the value in code_val is null. If try to do it manually  it throws parse numeric letter error.  how can i do it in first case.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have to send records from Aurora/Mysql to MSK and from there to Elastic search service  Aurora -->Kafka-connect--->AWS MSK--->kafka connect --->Elastic search  The record in Aurora table structure is something like this I think record will go to AWS MSK in this format.  So in order to consume by elastic search i need to use proper schema so schema registry i have to use. My question  Question 1  How should i use schema registry for above type of message schema registry is required ?. Do i have to create JSON structure for this and if yes where i have keep that. More help required here to understand this ? I have edited  Mentioned zookeper but i did not what is  How to link this to custom schema . Even i started and got this error  Which i was expecting because i did not do anything about schema . I do have jdbc connector installed and when i start i get below error  Question 2 Can i create two onnector on one ec2 (jdbc and elastic serach one ).If yes do i have to start both in sepearte cli ? Question 3 When i open vim /usr/local/confluent/etc/kafka-connect-jdbc/source-quickstart-sqlite.properties I see only propeties value like below  In the above properties file where i can mention schema name and table name? Based on answer i am updating my configuration for Kafka connect JDBC  ---------------start JDBC connect elastic search  ----------------------------- And then  Then i modified below properties  Last i modified  and here i modified below properties  When i list topic i do not see any topic listed for table name . Stack trace for the error message',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('Using Go, when fetching sheet data, the data is arriving with its applied cell formatting  i.e.  while I need the original . is there something in the api that can remove formatting? like  code:',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I ran into this, while looking up algorithms that find parity, which is supposedly efficient: Could some one please explain how this actually works?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have a pandas data frame with dates as indices. For example: I want to select just the first element of each available month. For example in this DF I want to select these: I have no idea how to do that. so I'm here to ask. Thanks in advance.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("So my database is structured like this: In my app I have two collectionViewControllers. The first one shows cells labeled category 1, category 2 etc. while the second collectionViewController should show cells with the items in each category. The problem is that my app will not retreive the different items under the category nodes no matter how I try. In the example above, printing snapshot.children prints zero (twice, for some reason), and printing item in snapshot.children.allobjects prints nothing.  In the first collectionViewController, which references the Categories node, I'm able to retrieve the category1 and category2 data like this: I've tried this exact method in my seccond collectionViewController referencing the Category1 node, without printing anything, just adding it to the category array in the viewcontroller and reloading the collectionView. The cells still show up blank.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("Trying to migrate a repo (including history) OUT of Git LFS.  I ran  (mentioned here) on a test repo, but it didn't work as expected and left LFS pointer files instead of converting them all to objects. I tried alternative methods, following this. Unfortunately it still left pointer files, so I combined it with this. In the end, I even ran all the commands together: Didn't work. Gave me the following error for multiple files, and the filtered commits have pointer files instead of the objects. I tried running the same commands on only the tip commit, and it seems like , , ,  don't show any modifications with . So I'm unable to re-add the cleaned/pulled object files to a new commit. Maybe that's the problem? So how to forcibly re-add unchanged file to index when using filter-branch? (Using Windows with git bash.)",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I\'m learning presto, and want to run Presto in my IDE. So I builded presto with "./mvnw clean install -DskipTests", following the instructions in this document: https://github.com/Teradata/presto. But I encountered an exception as follow My version of Presto is tag 0.229. How can I fix this problem?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have a table with schema: also I have on this table secondary index on column senderType. all the queries (until now) needed to be ordered by createdAt DESC but now I need to do a new query like: Is there any option to create this query besides materialized view? Thanks.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have a simple two tab application build around JavaFXML and scenebuilder. The tabs do nothing at present because I cannot get past a nullpointer exception when trying to load them. The java and fxml files are arranged in a Netbeans project like this: Main Application: The application main class MainApp.java sets the scene and is declared as follows: The MainController class declares the two tabs, the Input tab and Account tab, for the application and an exit button for closing the program. This is the MainView. fxml file: This is the java controller class for the main view contained in  MainController.java: The two println statements are simply trying to get the references to the two tabs, which are detailController and inputController, to do something. However, when these are uncommented and run, the following dump is output: When the printlns are commented out, the outcome is as expected, that is the tab pane is correctly displayed: As mentioned the detail and input controllers are empty, but for completeness they are as follows: InputView.fxml: The controller InputController.java: DetailView.fxml: The controller DetailController.java:',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have made dependency services on both side and Interface in shared library on Xamarin platform when i use it in xaml.cs hard coded it works but when i use it in ViewModel using messaging center to set count of notification in Toolbar of application it doesn't works  Does anyone have any kind of idea whats happening or should i do ? this code works from Xaml.cs page   And Below Code doesn't works InterFaceCode Dependency service BadgeDrawable Class",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
# ...
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have a Path object composed of PathElements  All 5 objects are drawn in the same style. - (MoveTo, LineTo, ArcTo, LineTo, ArcTo) I need a method that can calculate the center of an entire  object. And they can calculate it for all five objects. The idea is to calculate the center of both arcs (), to create a  that connects these centers, and the center of this  will be the center of an entire  object. But, I don't know how to calculate it simply. I got stuck in the calculation of the center of the arc. I need to calculate it independently of objects creation, but I have access to objects - I can get all the information about them.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have a compound view , where I have some checkboxes: CheckboxesView checkboxes_view_layout: In the respective class for this view, I have the following  I use this  in an , which obviosuly has its own Layout  MyActivity my_activity_layout:   checks for some value that is saved in preferences and if  returns false, I make  invisible by calling  as seen in the code above. In the app, this works perfectly. The preferences value is checked and if necessary the checkboxes are hidden. However, I dont want this to happen when I look at the preview of . Obviously the preview of  calls  which checks for the nonexisting preference which causes the view to never be visible in the preview. Is there a way for me to have a piece of code that is not called for a layout preview? For example: For those of you who are somewhat familiar with C# and VisualStudio, I basically want to do something in the lines of detecting design mode',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I'm using MySQL 5.6.  The internal app at my company works with (I know).  I've brought this up before but was told to just let it be. Today, I accidentally wrote and ran this , with a  instead of  and lo and behold all the rows deleted.  I understand delete all rows is allowable with the safe updates off, but why didn't this throw some syntax error?  What would  even mean in SQL?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have an Azure App Service with two slots. Is it possible to have these slots share a directory via Path Mappings or something along those lines?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('So I am following this tutorial and I have run into a problem, the code provided does not work with all the information I got/understood. The problem is on the first line (according to IntelliJ), "Modifier \'static\' not allowed here". But if I remove the \'static\' it does still not work. I would like to know how I can either fix this / work around this. I have read about static nested classes but I didn\'t get it to work with the other code in this post. It is probably something simple again that I have just missed, and I am sorry if that\'s the case.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("The  command in Vim output the current buffers in Vim. If one of the buffers is a terminal, there are some useful flags to examine there. For example, if the command was:  will contain this as one of the entries: Is there a vim function that could return such extended information about a buffer?  suggests that if  option is , the job had to have finished. before changes can be made to a terminal buffer, the 'modifiable' option must   be set.  This is only possible when the job has finished: To rephrase my question, how do I know the status of a shell process started with the  command?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("Yes, there is already the question Bulk Insert Optimization in .NET / EF Core. But this question is different. I ran into a scenario where I have to create a DB and populate it with processed/calculated/generated data. The amount of records is between 100 millions and 200 millions of records. Since seeding the data takes ages I can not do it on startup (of an web api). So I created a separated console application migrating the database and seeding it. It still takes ages (I even haven't finished a single run of seeding yet). Anything else what I can optimize in the main method (except removing console logs which are only there for debugging at the moment). Note this is the full working code. Copy and paste into a console app Program.cs and it compiles and runs. Required nugets: Microsoft.EntityFrameworkCore 3.1.0 Microsoft.EntityFrameworkCore.Relational 3.1.0 Microsoft.EntityFrameworkCore.SqlServer 3.1.0 Microsoft.EntityFrameworkCore.Tools 3.1.0",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have a folder with images (around 4500), I want to load them to feed a GAN that I already wrote, so I want to load my images in X_train like the CIFAR10 or MNIST load_data() function. I've tried this function (all the data in folder is with label 0..) : but it return a array of shape: EDIT : I think 3072 is because images are 32*32*3 ... and I want a array of the same shape as returned by MNIST or CIFAR10 load_data() : How can I change my function ? Thanks PS : I'm sorry, I'm beginner in Python so I dont understand well the mechanics above these systems : thanks for any help",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("After changing single-node to multi-node cluster, do you have to take any action to take advantage of cluster? For instance, our application server uses single  (our single-node's ip/port) to search documents. In addition, logstash, kibana, spark, they all point to the single ip/port.   Should I put a  to take advantage of the multi node? or do I get something for free maybe? I followed the following docker file (just changed network-mode to host and deployed on multiple hosts)",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("Consider the data set below, there is a factor  with 34 levels, I want to recode these levels according to  MWE Vectors Trial 1 Trial 2 Question The two trials as above didn't work. How to recode the old levels with the new ones using  family into a new variable say ?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have two vectors, A and B. I am computing a new vector, C, from A and B using mutate in dyplyr. The operation is a sum as I just want to concatenate the two variables into one (scores from a separate analyses within binary sex). In the case where both vectors have NA for a given row, I need the new vector C to reflect NA, not 0. Currently I am using: But this gives a '0' value if both A and B vectors have NA. I have scoured other posts on similar themes but can not distill what I need from them.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have a C++ application that is crashing on startup for some Windows 7 users. I can\'t reproduce the error on my own machine, but used breakpad to generate a .dmp file, which shows that the code is crashing with "Illegal instruction" initializing a static std::vector array. What could this possibly mean? Exception: The source at that line: The header: Dissasembly: Not sure if this matters, but in the most recent build I started distributing the Visual Studio runtime dlls directly in the application folder instead of executing vc_redist.exe.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("We stumbled upon this today: Why does adding the space work? Is the number literal being coerced or cast? I've tried some other tests to shed some light, but I can't quite understand what's going on behind-the-scenes:",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have a data frame with name paste0(i, "_SA") which is created in a loop.I want to print the 4th column but neither $ nor [,4] works. paste0(i, "_SA")[,4] gives error "incorrect number of dimensions" even though if I use this outside of the loop like US_SA[,4] it works. How do you refer to a column of paste0 named data frame?',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("So I am trying really hard to change the underlying number value of an . Take this example: With a simple extension methods for enums. In his method I want to remove all flags from the enum itself: Note that it is possible to set an enum to zero, even if there is no matching enum member. To clarify what I want to achieve, here a few samples:  should return  with the value of .  should return  with the value of . I actually achieved that, but it is hella ugly, at least IMO, by using some reflection. I really hope there is a cleaner and faster way to do this. I actually stumbled over the  field by some testing with reflection, which revealed that there is actually a public field which exposes the current value.  This also makes me wonder why you can't access it by using the dot (enumVal.value__)... I guess it is some kind of runtime field.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have 100 rows in my CSV file, I need to split them into 10 rows and perform some queries for every single stacks, because some rows have a specific column and some of them not. How can I do it in Pandas? I used PsychoPy for a neuroscience task and the task has 10 trials, because of that PsychoPy stores RTs (Reaction Times) in different 10 columns, so I need to access them to for example evaluating blue circles in the first trial which their RTs is 1 or yellow circles in second trial which their RTs is 0.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('My colleagues and I have several versions of Visual Studio installed which — for business reasons — we may need to keep for some time. For some teammates an inconvenient version of Visual Studio will open when cloning a git repository from Azure DevOps server, starting from this web UI: How can we ensure the preferred version of VS opens upon/after cloning?  As a bonus, would there be any way to configure this per repository? So far the best we have worked out is to follow these steps.  However it doesn\'t seem to consistently update the preference for every user.  In particular, if a team member has already cloned at least once targeting an earlier version (e.g. VS 2015, VS 2017) we seem to have a dickens of a time getting an update of this preference to VS 2019 to stick. Open “Default Apps” in system settings Select “Choose default apps by protocol” Scroll to “Microsoft Visual Studio Web Protocol Handler Selector" Change handler to Visual Studio 2019 Note: Our machines have MS VS Web Protocol Handler Selector listed twice. We have experimented with setting both or either without success. Any suggestions why we\'re seeing the protocol selector twice may also help.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I have a token scanner that simply returns  for characters I'm not interested in. Rather than  the nils to my token vector and then later stripping them all out, I want to simply not add them. I'm using to do this. Is there a specific operator or a more concise implementation?",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have 2 cloudformation templates - one that creates a kms key and the other template uses the kms key to encrypt a env variable used in the lambda function. I wanted to know if there is a way to run the kms encrypt command from within the cloudformation as a prior step and then use the encrypted text for the environment variable while creating the lambda function. This command outputs the encrypted text and I would need to use this text in the lambda function for one of the environment variables as below. If this is not possible is there any recommendations on how to achieve this? Thanks in advance.',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ("I am trying to combine multiple sheets from different excel files into one dataframe. All the files have multiple sheets, and one of these sheets has the same name in all the files - this is the sheet that I am interested in combining into one dataframe. All the files are in the same directory.   The result of variable a (files function) is a list of the files that meet the naming criteria. But the result of variable b (extract_tab function) is an empty dataframe. What am I doing wrong? I looked at this postImport multiple excel files into python pandas and concatenate them into one dataframe but it doesn't work... although I did take a couple of ideas from it.",
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ('I have an array that contains multiple objects with functions . Now I want to construct a new object signature with a function  that inherits all signatures from the array item  functions. unfortunately, I am getting  This is not callable, as the signatures are conflicting. Is there a way to get (AND instead of OR) ? playground',
#   {'cats': {'python': 0.0,
#     'other': 0.0,
#     'javascript': 0.0,
#     'r': 0.0,
#     'pandas': 0.0,
#     'java': 0.0,
#     'c++': 0.0,
#     'c#': 0.0,
#     'python-3.x': 0.0,
#     'sql': 0.0}}),
#  ...]

# %%
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'textcat']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fe5a1068331f> in <module>
# ----> 1 other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'textcat']
#
# NameError: name 'nlp' is not defined

# %%
from spacy.util import minibatch
from spacy.training import Example

nlp = spacy.load("en_core_web_sm")

if 'textcat_multilabel' not in nlp.pipe_names:
    textcat_multilabel = nlp.create_pipe('textcat_multilabel')
    nlp.add_pipe('textcat_multilabel', last=True)
else:
    textcat_multilabel = nlp.get_pipe('textcat_multilabel')
    
for label in categories.index:
    textcat_multilabel.add_label(label)


# with nlp.disable_pipes(*other_pipes):
with nlp.select_pipes(enable="textcat_multilabel"):

#     optimizer = nlp.begin_training()
#     optimizer = nlp.create_optimizer()
    optimizer = nlp.resume_training()
    for i in range(5):
        print('Epoch %d' % i)
        losses = {}
#         batches = minibatch(data_train_spacy, size=128)
        batches = minibatch(data_train_spacy, size=8)
        for batch in batches:
#             texts, annotations = zip(*batch)
#             nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
#                        losses=losses)
            for text, annotations in batch:
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                nlp.update([example], drop=0.2, sgd=optimizer, losses=losses)
#         with textcat_multilabel.model.use_params(optimizer.averages):
#             docs = [nlp.tokenizer(h) for h in data_test.bs4]
#             test_pred = np.array(
#                 [sorted(doc.cats.items(), key=lambda x: -x[1])[0][0]
#                  for doc in textcat_multilabel.pipe(docs)])
#             print('Test Acc: %.4f' %
#                   (pd.Series(test_pred == data_test.category.values).sum() / data_test.shape[0]))
# Out:
# Epoch 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-808e2019b22a> in <module>
#      32                 doc = nlp.make_doc(text)
#      33                 example = Example.from_dict(doc, annotations)
# ---> 34                 nlp.update([example], drop=0.2, sgd=optimizer, losses=losses)
#      35 #         with textcat_multilabel.model.use_params(optimizer.averages):
#      36 #             docs = [nlp.tokenizer(h) for h in data_test.bs4]
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\language.py in update(self, examples, _, drop, sgd, losses, component_cfg, exclude)
#    1105             if name in exclude or not hasattr(proc, "update"):
#    1106                 continue
# -> 1107             proc.update(examples, sgd=None, losses=losses, **component_cfg[name])
#    1108         if sgd not in (None, False):
#    1109             for name, proc in self.pipeline:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\textcat.py in update(self, examples, drop, sgd, losses)
#     201             return losses
#     202         set_dropout_rate(self.model, drop)
# --> 203         scores, bp_scores = self.model.begin_update([eg.predicted for eg in examples])
#     204         loss, d_scores = self.get_loss(examples, scores)
#     205         bp_scores(d_scores)
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in begin_update(self, X)
#     304         and returns the gradient with respect to the input.
#     305         """
# --> 306         return self._func(self, X, is_train=True)
#     307
#     308     def predict(self, X: InT) -> OutT:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\concatenate.py in forward(model, X, is_train)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         return _list_forward(model, X, Ys, callbacks, is_train)  # type: ignore
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\concatenate.py in <listcomp>(.0)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         return _list_forward(model, X, Ys, callbacks, is_train)  # type: ignore
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\with_cpu.py in forward(model, X, is_train)
#      22
#      23 def forward(model: Model, X: Any, is_train: bool) -> Tuple[Any, Callable]:
# ---> 24     cpu_outputs, backprop = model.layers[0].begin_update(_to_cpu(X))
#      25     gpu_outputs = _to_device(model.ops, cpu_outputs)
#      26
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in begin_update(self, X)
#     304         and returns the gradient with respect to the input.
#     305         """
# --> 306         return self._func(self, X, is_train=True)
#     307
#     308     def predict(self, X: InT) -> OutT:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\sparselinear.pyx in thinc.layers.sparselinear.forward()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\sparselinear.pyx in thinc.layers.sparselinear._begin_cpu_update()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in get_dim(self, name)
#     173         if value is None:
#     174             err = f"Cannot get dimension '{name}' for model '{self.name}': value unset"
# --> 175             raise ValueError(err)
#     176         else:
#     177             return value
#
# ValueError: Cannot get dimension 'nO' for model 'sparse_linear': value unset

# %%
for doc in list(textcat_multilabel.pipe(docs)):
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-f26736c4b42e> in <module>
# ----> 1 for doc in list(textcat_multilabel.pipe(docs)):
#       2     print(doc)
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in pipe()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\util.py in raise_error(proc_name, proc, docs, e)
#    1496
#    1497 def raise_error(proc_name, proc, docs, e):
# -> 1498     raise e
#    1499
#    1500
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.pipe()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\textcat.py in predict(self, docs)
#     156             scores = xp.zeros((len(docs), len(self.labels)))
#     157             return scores
# --> 158         scores = self.model.predict(docs)
#     159         scores = self.model.ops.asarray(scores)
#     160         return scores
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\concatenate.py in forward(model, X, is_train)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         return _list_forward(model, X, Ys, callbacks, is_train)  # type: ignore
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\concatenate.py in <listcomp>(.0)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         return _list_forward(model, X, Ys, callbacks, is_train)  # type: ignore
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\with_cpu.py in forward(model, X, is_train)
#      22
#      23 def forward(model: Model, X: Any, is_train: bool) -> Tuple[Any, Callable]:
# ---> 24     cpu_outputs, backprop = model.layers[0].begin_update(_to_cpu(X))
#      25     gpu_outputs = _to_device(model.ops, cpu_outputs)
#      26
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in begin_update(self, X)
#     304         and returns the gradient with respect to the input.
#     305         """
# --> 306         return self._func(self, X, is_train=True)
#     307
#     308     def predict(self, X: InT) -> OutT:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\sparselinear.pyx in thinc.layers.sparselinear.forward()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\sparselinear.pyx in thinc.layers.sparselinear._begin_cpu_update()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in get_dim(self, name)
#     173         if value is None:
#     174             err = f"Cannot get dimension '{name}' for model '{self.name}': value unset"
# --> 175             raise ValueError(err)
#     176         else:
#     177             return value
#
# ValueError: Cannot get dimension 'nO' for model 'sparse_linear': value unset

# %%
for doc in textcat.pipe(docs):
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-f66fef080832> in <module>
# ----> 1 for doc in textcat.pipe(docs):
#       2     print(doc)
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in pipe()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\util.py in raise_error(proc_name, proc, docs, e)
#    1496
#    1497 def raise_error(proc_name, proc, docs, e):
# -> 1498     raise e
#    1499
#    1500
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.pipe()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\spacy\pipeline\textcat.py in predict(self, docs)
#     156             scores = xp.zeros((len(docs), len(self.labels)))
#     157             return scores
# --> 158         scores = self.model.predict(docs)
#     159         scores = self.model.ops.asarray(scores)
#     160         return scores
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\concatenate.py in forward(model, X, is_train)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         return _list_forward(model, X, Ys, callbacks, is_train)  # type: ignore
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\concatenate.py in <listcomp>(.0)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         return _list_forward(model, X, Ys, callbacks, is_train)  # type: ignore
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\with_cpu.py in forward(model, X, is_train)
#      22
#      23 def forward(model: Model, X: Any, is_train: bool) -> Tuple[Any, Callable]:
# ---> 24     cpu_outputs, backprop = model.layers[0].begin_update(_to_cpu(X))
#      25     gpu_outputs = _to_device(model.ops, cpu_outputs)
#      26
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in begin_update(self, X)
#     304         and returns the gradient with respect to the input.
#     305         """
# --> 306         return self._func(self, X, is_train=True)
#     307
#     308     def predict(self, X: InT) -> OutT:
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\sparselinear.pyx in thinc.layers.sparselinear.forward()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\layers\sparselinear.pyx in thinc.layers.sparselinear._begin_cpu_update()
#
# c:\users\vince\miniconda3\envs\tfml\lib\site-packages\thinc\model.py in get_dim(self, name)
#     173         if value is None:
#     174             err = f"Cannot get dimension '{name}' for model '{self.name}': value unset"
# --> 175             raise ValueError(err)
#     176         else:
#     177             return value
#
# ValueError: Cannot get dimension 'nO' for model 'sparse_linear': value unset

# %%
docs = [nlp.tokenizer(h) for h in data_test.bs4]

# %%
textcat.pipe(docs)
